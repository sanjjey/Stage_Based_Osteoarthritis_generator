# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("jeftaadriel/osteoarthritis-initiative-oai-dataset")

print("Path to dataset files:", path)
# Out:
# Warning: Looks like you're using an outdated `kagglehub` version (installed: 0.3.12), please consider upgrading to the latest version (0.3.13).
# Path to dataset files: C:\Users\Sanjjey Arumugam\.cache\kagglehub\datasets\jeftaadriel\osteoarthritis-initiative-oai-dataset\versions\1

# %%
### Cell 1: Imports & Environment
import os
import random
from pathlib import Path
import numpy as np
import pandas as pd
from PIL import Image
import matplotlib.pyplot as plt
from tqdm.notebook import tqdm

import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader
from torchvision import transforms, utils

# device
DEVICE = "cuda" if torch.cuda.is_available() else "cpu"
print("Device:", DEVICE)
# Out:
# Device: cuda

# %%
print(path)
# Out:
# C:\Users\Sanjjey Arumugam\.cache\kagglehub\datasets\jeftaadriel\osteoarthritis-initiative-oai-dataset\versions\1

# %%
path_two=path+"\train"

# %%
print(path_two)
# Out:
# C:\Users\Sanjjey Arumugam\.cache\kagglehub\datasets\jeftaadriel\osteoarthritis-initiative-oai-dataset\versions\1	rain

# %%
# Download dataset with kagglehub
import kagglehub

path = kagglehub.dataset_download("jeftaadriel/osteoarthritis-initiative-oai-dataset")
print("Dataset downloaded at:", path)

DATA_ROOT=path
SAVE_DIR = "./results"
# Define all splits
SPLITS = ["train", "val", "test", "auto_test"]

# Just to verify
for split in SPLITS:
    stage_dirs = [d.name for d in Path(DATA_ROOT, split).iterdir() if d.is_dir()]
    print(f"{split}: {stage_dirs}")
# Out:
# Warning: Looks like you're using an outdated `kagglehub` version (installed: 0.3.12), please consider upgrading to the latest version (0.3.13).
# Dataset downloaded at: C:\Users\Sanjjey Arumugam\.cache\kagglehub\datasets\jeftaadriel\osteoarthritis-initiative-oai-dataset\versions\1
# train: ['0', '1', '2', '3', '4']
# val: ['0', '1', '2', '3', '4']
# test: ['0', '1', '2', '3', '4']
# auto_test: ['0', '1', '2', '3', '4']

# %%
IMG_SIZE = 128
BATCH_SIZE = 32
NZ = 128        # latent vector size
N_STAGES = 5    # 0..4
N_SIDES = 2     # left, right
EPOCHS = 500
LR = 2e-4

# %%
class OAIDataset(Dataset):
    def __init__(self, root, split="train", image_size=128):
        self.root = Path(root) / split
        self.samples = []
        self.transform = transforms.Compose([
            transforms.Resize((image_size, image_size)),
            transforms.Grayscale(num_output_channels=1),
            transforms.ToTensor(),
            transforms.Normalize([0.5], [0.5])  # [-1,1]
        ])
        for stage_folder in sorted(self.root.iterdir()):
            stage = int(stage_folder.name)  # 0..4
            for img_path in stage_folder.glob("*.png"):
                side = 0  # default: right
                if "_2.png" in img_path.name:
                    side = 1  # left
                self.samples.append((img_path, stage, side))

    def __len__(self): return len(self.samples)

    def __getitem__(self, idx):
        img_path, stage, side = self.samples[idx]
        img = Image.open(img_path).convert("L")
        img = self.transform(img)
        return img, torch.tensor(stage), torch.tensor(side)

# %%
train_ds = OAIDataset(DATA_ROOT, "train", IMG_SIZE)
val_ds   = OAIDataset(DATA_ROOT, "val", IMG_SIZE)
test_ds  = OAIDataset(DATA_ROOT, "test", IMG_SIZE)
auto_ds  = OAIDataset(DATA_ROOT, "auto_test", IMG_SIZE)

train_loader = DataLoader(train_ds, batch_size=BATCH_SIZE, shuffle=True)
val_loader   = DataLoader(val_ds, batch_size=BATCH_SIZE, shuffle=False)

print("Train:", len(train_ds), "Val:", len(val_ds), "Test:", len(test_ds), "Auto:", len(auto_ds))

# Visualize some samples
imgs, stages, sides = next(iter(train_loader))
grid = utils.make_grid(imgs[:16], nrow=4, normalize=True)
plt.figure(figsize=(6,6))
plt.imshow(np.transpose(grid, (1,2,0)))
plt.axis("off")
plt.title("Sample Training Images")
plt.show()

print("Stages:", stages[:8].tolist())
print("Sides :", sides[:8].tolist(), " (0=Right, 1=Left)")
# Out:
# Train: 5778 Val: 826 Test: 1656 Auto: 1526
# Stages: [1, 2, 0, 0, 0, 0, 2, 0]
# Sides : [0, 0, 0, 0, 0, 0, 0, 0]  (0=Right, 1=Left)

# %%
class Generator(nn.Module):
    def __init__(self, nz=128, ngf=64, nc=1, n_stage=5, n_side=2, image_size=128):
        super().__init__()
        self.stage_emb = nn.Embedding(n_stage, n_stage)
        self.side_emb  = nn.Embedding(n_side, n_side)
        self.init_size = image_size // 16
        cond_dim = n_stage + n_side
        self.fc = nn.Linear(nz + cond_dim, ngf*8*self.init_size*self.init_size)

        def block(in_feat, out_feat):
            return nn.Sequential(
                nn.Upsample(scale_factor=2),
                nn.Conv2d(in_feat, out_feat, 3, padding=1),
                nn.BatchNorm2d(out_feat),
                nn.ReLU(True)
            )
        self.conv_blocks = nn.Sequential(
            block(ngf*8, ngf*4),
            block(ngf*4, ngf*2),
            block(ngf*2, ngf),
            block(ngf, ngf//2),
            nn.Conv2d(ngf//2, nc, 3, padding=1),
            nn.Tanh()
        )

    def forward(self, z, stage, side):
        cond = torch.cat([self.stage_emb(stage), self.side_emb(side)], dim=1)
        x = torch.cat([z, cond], dim=1)
        out = self.fc(x).view(x.size(0), -1, self.init_size, self.init_size)
        return self.conv_blocks(out)

class Discriminator(nn.Module):
    def __init__(self, ndf=64, nc=1, n_stage=5, n_side=2, image_size=128):
        super().__init__()
        self.stage_emb = nn.Embedding(n_stage, n_stage)
        self.side_emb  = nn.Embedding(n_side, n_side)

        def block(in_c, out_c, stride=2):
            return nn.Sequential(
                nn.Conv2d(in_c, out_c, 4, stride, 1),
                nn.BatchNorm2d(out_c),
                nn.LeakyReLU(0.2, inplace=True)
            )
        self.model = nn.Sequential(
            nn.Conv2d(nc+1, ndf, 4, 2, 1), nn.LeakyReLU(0.2, inplace=True),
            block(ndf, ndf*2),
            block(ndf*2, ndf*4),
            block(ndf*4, ndf*8),
            nn.Conv2d(ndf*8, 1, 4, 1)
        )

    def forward(self, x, stage, side):
        B, _, H, W = x.shape
        cond = torch.cat([self.stage_emb(stage), self.side_emb(side)], dim=1)
        emb_map = cond.unsqueeze(-1).unsqueeze(-1).expand(-1, cond.size(1), H, W).sum(1, keepdim=True)
        out = self.model(torch.cat([x, emb_map], 1))
        return out.mean(dim=[1,2,3])  # scalar per image

# %%
# Instantiate models after defining Generator and Discriminator
netG = Generator(NZ, n_stage=N_STAGES, n_side=N_SIDES).to(DEVICE)
netD = Discriminator(n_stage=N_STAGES, n_side=N_SIDES).to(DEVICE)

optG = torch.optim.Adam(netG.parameters(), lr=LR, betas=(0.5, 0.999))
optD = torch.optim.Adam(netD.parameters(), lr=LR, betas=(0.5, 0.999))
criterion = nn.BCEWithLogitsLoss()

# fixed noise & labels for monitoring
fixed_noise = torch.randn(N_STAGES * N_SIDES * 2, NZ, device=DEVICE)
fixed_stage = torch.tensor([s for s in range(N_STAGES) for _ in range(N_SIDES*2)], device=DEVICE)
fixed_side  = torch.tensor([side for _ in range(N_STAGES) for side in [0,1,0,1]], device=DEVICE)

# %%
for epoch in range(1, EPOCHS+1):
    netG.train()
    netD.train()

    for imgs, stages, sides in train_loader:
        imgs, stages, sides = imgs.to(DEVICE), stages.to(DEVICE), sides.to(DEVICE)
        B = imgs.size(0)
        valid, fake = torch.ones(B, device=DEVICE), torch.zeros(B, device=DEVICE)

        # ---------------- Train D ----------------
        optD.zero_grad()
        real_loss = criterion(netD(imgs, stages, sides), valid)
        z = torch.randn(B, NZ, device=DEVICE)
        gen_imgs = netG(z, stages, sides)
        fake_loss = criterion(netD(gen_imgs.detach(), stages, sides), fake)
        d_loss = 0.5 * (real_loss + fake_loss)
        d_loss.backward()
        optD.step()

        # ---------------- Train G ----------------
        optG.zero_grad()
        g_loss = criterion(netD(gen_imgs, stages, sides), valid)
        g_loss.backward()
        optG.step()

    # ---------------- Save Samples every 50 epochs ----------------
    if epoch % 50 == 0:
        with torch.no_grad():
            netG.eval()
            sample = netG(fixed_noise, fixed_stage, fixed_side).cpu()
            grid = utils.make_grid((sample+1)/2, nrow=8)
            utils.save_image(grid, f"{SAVE_DIR}/samples_epoch_{epoch:03d}.png")

    # ---------------- Save Model Checkpoints every 100 epochs ----------------
    if epoch % 100 == 0:
        torch.save({
            "epoch": epoch,
            "netG_state_dict": netG.state_dict(),
            "netD_state_dict": netD.state_dict(),
            "optG_state_dict": optG.state_dict(),
            "optD_state_dict": optD.state_dict(),
            "g_loss": g_loss.item(),
            "d_loss": d_loss.item()
        }, f"{SAVE_DIR}/checkpoint_epoch_{epoch:03d}.pth")

    print(f"Epoch {epoch}/{EPOCHS} - D_loss: {d_loss.item():.3f}, G_loss: {g_loss.item():.3f}")
# Out:
# Epoch 1/500 - D_loss: 0.663, G_loss: 0.742
# Epoch 2/500 - D_loss: 0.686, G_loss: 0.791
# Epoch 3/500 - D_loss: 0.703, G_loss: 0.698
# Epoch 4/500 - D_loss: 0.704, G_loss: 0.685
# Epoch 5/500 - D_loss: 0.703, G_loss: 0.700
# Epoch 6/500 - D_loss: 0.696, G_loss: 0.707
# Epoch 7/500 - D_loss: 0.689, G_loss: 0.704
# Epoch 8/500 - D_loss: 0.682, G_loss: 0.763
# Epoch 9/500 - D_loss: 0.687, G_loss: 0.709
# Epoch 10/500 - D_loss: 0.672, G_loss: 0.734
# Epoch 11/500 - D_loss: 0.691, G_loss: 0.707
# Epoch 12/500 - D_loss: 0.694, G_loss: 0.747
# Epoch 13/500 - D_loss: 0.712, G_loss: 0.722
# Epoch 14/500 - D_loss: 0.705, G_loss: 0.718
# Epoch 15/500 - D_loss: 0.702, G_loss: 0.706
# Epoch 16/500 - D_loss: 0.687, G_loss: 0.707
# Epoch 17/500 - D_loss: 0.692, G_loss: 0.698
# Epoch 18/500 - D_loss: 0.702, G_loss: 0.722
# Epoch 19/500 - D_loss: 0.693, G_loss: 0.677
# Epoch 20/500 - D_loss: 0.683, G_loss: 0.771
# Epoch 21/500 - D_loss: 0.698, G_loss: 0.705
# Epoch 22/500 - D_loss: 0.737, G_loss: 0.701
# Epoch 23/500 - D_loss: 0.694, G_loss: 0.764
# Epoch 24/500 - D_loss: 0.680, G_loss: 0.808
# Epoch 25/500 - D_loss: 0.698, G_loss: 0.828
# Epoch 26/500 - D_loss: 0.701, G_loss: 0.731
# Epoch 27/500 - D_loss: 0.671, G_loss: 0.826
# Epoch 28/500 - D_loss: 0.692, G_loss: 0.840
# Epoch 29/500 - D_loss: 0.708, G_loss: 0.697
# Epoch 30/500 - D_loss: 0.721, G_loss: 0.758
# Epoch 31/500 - D_loss: 0.666, G_loss: 0.760
# Epoch 32/500 - D_loss: 0.723, G_loss: 0.734
# Epoch 33/500 - D_loss: 0.735, G_loss: 0.701
# Epoch 34/500 - D_loss: 0.720, G_loss: 0.820
# Epoch 35/500 - D_loss: 0.690, G_loss: 0.780
# Epoch 36/500 - D_loss: 0.673, G_loss: 0.900
# Epoch 37/500 - D_loss: 0.722, G_loss: 0.816
# Epoch 38/500 - D_loss: 0.648, G_loss: 0.896
# Epoch 39/500 - D_loss: 0.673, G_loss: 0.818
# Epoch 40/500 - D_loss: 0.669, G_loss: 0.958
# Epoch 41/500 - D_loss: 0.684, G_loss: 0.822
# Epoch 42/500 - D_loss: 0.659, G_loss: 0.797
# Epoch 43/500 - D_loss: 0.748, G_loss: 0.689
# Epoch 44/500 - D_loss: 0.641, G_loss: 0.887
# Epoch 45/500 - D_loss: 0.662, G_loss: 0.816
# Epoch 46/500 - D_loss: 0.642, G_loss: 0.796
# Epoch 47/500 - D_loss: 0.564, G_loss: 1.083
# Epoch 48/500 - D_loss: 0.652, G_loss: 0.791
# Epoch 49/500 - D_loss: 0.630, G_loss: 0.942
# Epoch 50/500 - D_loss: 0.641, G_loss: 0.916
# Epoch 51/500 - D_loss: 0.649, G_loss: 0.868
# Epoch 52/500 - D_loss: 0.849, G_loss: 0.974
# Epoch 53/500 - D_loss: 0.656, G_loss: 0.827
# Epoch 54/500 - D_loss: 0.660, G_loss: 0.677
# Epoch 55/500 - D_loss: 0.633, G_loss: 0.924
# Epoch 56/500 - D_loss: 0.721, G_loss: 0.980
# Epoch 57/500 - D_loss: 0.594, G_loss: 1.070
# Epoch 58/500 - D_loss: 0.564, G_loss: 1.254
# Epoch 59/500 - D_loss: 0.558, G_loss: 1.268
# Epoch 60/500 - D_loss: 0.575, G_loss: 0.922
# Epoch 61/500 - D_loss: 0.787, G_loss: 1.137
# Epoch 62/500 - D_loss: 0.604, G_loss: 1.006
# Epoch 63/500 - D_loss: 0.691, G_loss: 0.908
# Epoch 64/500 - D_loss: 0.674, G_loss: 0.661
# Epoch 65/500 - D_loss: 0.674, G_loss: 1.312
# Epoch 66/500 - D_loss: 0.626, G_loss: 1.283
# Epoch 67/500 - D_loss: 0.627, G_loss: 0.829
# Epoch 68/500 - D_loss: 0.656, G_loss: 0.765
# Epoch 69/500 - D_loss: 0.542, G_loss: 0.907
# Epoch 70/500 - D_loss: 0.459, G_loss: 1.782
# Epoch 71/500 - D_loss: 0.536, G_loss: 1.071
# Epoch 72/500 - D_loss: 0.602, G_loss: 1.128
# Epoch 73/500 - D_loss: 0.518, G_loss: 1.385
# Epoch 74/500 - D_loss: 0.409, G_loss: 1.209
# Epoch 75/500 - D_loss: 0.568, G_loss: 1.489
# Epoch 76/500 - D_loss: 0.617, G_loss: 1.395
# Epoch 77/500 - D_loss: 0.739, G_loss: 0.585
# Epoch 78/500 - D_loss: 0.465, G_loss: 1.420
# Epoch 79/500 - D_loss: 0.574, G_loss: 0.667
# Epoch 80/500 - D_loss: 0.398, G_loss: 1.977
# Epoch 81/500 - D_loss: 0.486, G_loss: 1.731
# Epoch 82/500 - D_loss: 0.525, G_loss: 2.075
# Epoch 83/500 - D_loss: 0.300, G_loss: 1.896
# Epoch 84/500 - D_loss: 0.437, G_loss: 1.605
# Epoch 85/500 - D_loss: 0.535, G_loss: 2.327
# Epoch 86/500 - D_loss: 0.479, G_loss: 1.823
# Epoch 87/500 - D_loss: 0.549, G_loss: 1.495
# Epoch 88/500 - D_loss: 0.390, G_loss: 1.759
# Epoch 89/500 - D_loss: 0.288, G_loss: 1.920
# Epoch 90/500 - D_loss: 0.415, G_loss: 1.823
# Epoch 91/500 - D_loss: 0.378, G_loss: 1.845
# Epoch 92/500 - D_loss: 0.544, G_loss: 1.211
# Epoch 93/500 - D_loss: 0.646, G_loss: 1.124
# Epoch 94/500 - D_loss: 0.416, G_loss: 1.565
# Epoch 95/500 - D_loss: 0.397, G_loss: 1.582
# Epoch 96/500 - D_loss: 0.435, G_loss: 1.788
# Epoch 97/500 - D_loss: 0.393, G_loss: 1.707
# Epoch 98/500 - D_loss: 0.358, G_loss: 2.090
# Epoch 99/500 - D_loss: 0.556, G_loss: 2.021
# Epoch 100/500 - D_loss: 0.467, G_loss: 1.889
# Epoch 101/500 - D_loss: 0.292, G_loss: 2.498
# Epoch 102/500 - D_loss: 0.146, G_loss: 2.368
# Epoch 103/500 - D_loss: 0.236, G_loss: 4.474
# Epoch 104/500 - D_loss: 0.282, G_loss: 2.462
# Epoch 105/500 - D_loss: 0.209, G_loss: 3.036
# Epoch 106/500 - D_loss: 0.744, G_loss: 2.733
# Epoch 107/500 - D_loss: 0.520, G_loss: 1.691
# Epoch 108/500 - D_loss: 0.267, G_loss: 1.825
# Epoch 109/500 - D_loss: 0.400, G_loss: 1.662
# Epoch 110/500 - D_loss: 0.429, G_loss: 2.205
# Epoch 111/500 - D_loss: 0.329, G_loss: 1.926
# Epoch 112/500 - D_loss: 0.302, G_loss: 4.220
# Epoch 113/500 - D_loss: 0.358, G_loss: 2.293
# Epoch 114/500 - D_loss: 0.332, G_loss: 1.956
# Epoch 115/500 - D_loss: 0.171, G_loss: 3.374
# Epoch 116/500 - D_loss: 0.388, G_loss: 1.990
# Epoch 117/500 - D_loss: 0.261, G_loss: 1.665
# Epoch 118/500 - D_loss: 0.402, G_loss: 1.557
# Epoch 119/500 - D_loss: 0.219, G_loss: 2.232
# Epoch 120/500 - D_loss: 0.286, G_loss: 1.748
# Epoch 121/500 - D_loss: 0.290, G_loss: 1.738
# Epoch 122/500 - D_loss: 0.190, G_loss: 2.379
# Epoch 123/500 - D_loss: 0.348, G_loss: 1.771
# Epoch 124/500 - D_loss: 0.337, G_loss: 3.118
# Epoch 125/500 - D_loss: 0.230, G_loss: 2.508
# Epoch 126/500 - D_loss: 0.222, G_loss: 2.819
# Epoch 127/500 - D_loss: 0.330, G_loss: 2.477
# Epoch 128/500 - D_loss: 0.138, G_loss: 2.777
# Epoch 129/500 - D_loss: 0.507, G_loss: 1.141
# Epoch 130/500 - D_loss: 0.110, G_loss: 3.615
# Epoch 131/500 - D_loss: 0.200, G_loss: 3.918
# Epoch 132/500 - D_loss: 0.257, G_loss: 2.421
# Epoch 133/500 - D_loss: 0.339, G_loss: 1.656
# Epoch 134/500 - D_loss: 0.350, G_loss: 1.942
# Epoch 135/500 - D_loss: 0.168, G_loss: 2.462
# Epoch 136/500 - D_loss: 0.148, G_loss: 2.187
# Epoch 137/500 - D_loss: 0.240, G_loss: 2.200
# Epoch 138/500 - D_loss: 0.302, G_loss: 2.236
# Epoch 139/500 - D_loss: 0.110, G_loss: 2.907
# Epoch 140/500 - D_loss: 0.210, G_loss: 3.449
# Epoch 141/500 - D_loss: 0.211, G_loss: 2.797
# Epoch 142/500 - D_loss: 0.306, G_loss: 2.480
# Epoch 143/500 - D_loss: 0.143, G_loss: 3.490
# Epoch 144/500 - D_loss: 0.160, G_loss: 2.148
# Epoch 145/500 - D_loss: 0.333, G_loss: 1.555
# Epoch 146/500 - D_loss: 0.161, G_loss: 3.368
# Epoch 147/500 - D_loss: 0.184, G_loss: 2.873
# Epoch 148/500 - D_loss: 0.045, G_loss: 4.263
# Epoch 149/500 - D_loss: 0.118, G_loss: 3.505
# Epoch 150/500 - D_loss: 0.205, G_loss: 2.684
# Epoch 151/500 - D_loss: 0.397, G_loss: 1.674
# Epoch 152/500 - D_loss: 0.110, G_loss: 4.299
# Epoch 153/500 - D_loss: 0.142, G_loss: 3.671
# Epoch 154/500 - D_loss: 0.332, G_loss: 1.671
# Epoch 155/500 - D_loss: 0.259, G_loss: 2.248
# Epoch 156/500 - D_loss: 0.309, G_loss: 3.554
# Epoch 157/500 - D_loss: 0.290, G_loss: 1.414
# Epoch 158/500 - D_loss: 0.107, G_loss: 4.872
# Epoch 159/500 - D_loss: 0.247, G_loss: 3.395
# Epoch 160/500 - D_loss: 0.094, G_loss: 3.660
# Epoch 161/500 - D_loss: 0.199, G_loss: 3.884
# Epoch 162/500 - D_loss: 0.043, G_loss: 5.842
# Epoch 163/500 - D_loss: 0.067, G_loss: 4.168
# Epoch 164/500 - D_loss: 0.089, G_loss: 4.902
# Epoch 165/500 - D_loss: 0.126, G_loss: 4.403
# Epoch 166/500 - D_loss: 0.260, G_loss: 2.913
# Epoch 167/500 - D_loss: 0.156, G_loss: 3.919
# Epoch 168/500 - D_loss: 0.159, G_loss: 3.092
# Epoch 169/500 - D_loss: 0.092, G_loss: 3.163
# Epoch 170/500 - D_loss: 0.099, G_loss: 2.824
# Epoch 171/500 - D_loss: 0.081, G_loss: 4.536
# Epoch 172/500 - D_loss: 0.346, G_loss: 1.554
# Epoch 173/500 - D_loss: 0.188, G_loss: 3.422
# Epoch 174/500 - D_loss: 0.118, G_loss: 5.844
# Epoch 175/500 - D_loss: 0.219, G_loss: 5.015
# Epoch 176/500 - D_loss: 0.117, G_loss: 4.003
# Epoch 177/500 - D_loss: 0.065, G_loss: 4.094
# Epoch 178/500 - D_loss: 0.064, G_loss: 4.638
# Epoch 179/500 - D_loss: 0.192, G_loss: 3.237
# Epoch 180/500 - D_loss: 0.277, G_loss: 2.408
# Epoch 181/500 - D_loss: 0.138, G_loss: 3.149
# Epoch 182/500 - D_loss: 0.040, G_loss: 5.161
# Epoch 183/500 - D_loss: 0.070, G_loss: 4.468
# Epoch 184/500 - D_loss: 0.198, G_loss: 3.523
# Epoch 185/500 - D_loss: 0.233, G_loss: 4.428
# Epoch 186/500 - D_loss: 0.064, G_loss: 4.574
# Epoch 187/500 - D_loss: 0.118, G_loss: 4.451
# Epoch 188/500 - D_loss: 0.059, G_loss: 4.565
# Epoch 189/500 - D_loss: 0.183, G_loss: 4.911
# Epoch 190/500 - D_loss: 0.133, G_loss: 3.179
# Epoch 191/500 - D_loss: 0.126, G_loss: 3.689
# Epoch 192/500 - D_loss: 0.062, G_loss: 3.633
# Epoch 193/500 - D_loss: 0.037, G_loss: 4.358
# Epoch 194/500 - D_loss: 0.146, G_loss: 5.241
# Epoch 195/500 - D_loss: 0.095, G_loss: 6.338
# Epoch 196/500 - D_loss: 0.134, G_loss: 3.406
# Epoch 197/500 - D_loss: 0.044, G_loss: 3.877
# Epoch 198/500 - D_loss: 0.723, G_loss: 1.762
# Epoch 199/500 - D_loss: 0.048, G_loss: 4.762
# Epoch 200/500 - D_loss: 0.044, G_loss: 5.218
# Epoch 201/500 - D_loss: 0.085, G_loss: 6.613
# Epoch 202/500 - D_loss: 0.016, G_loss: 5.916
# Epoch 203/500 - D_loss: 0.107, G_loss: 5.071
# Epoch 204/500 - D_loss: 0.121, G_loss: 3.810
# Epoch 205/500 - D_loss: 0.210, G_loss: 9.001
# Epoch 206/500 - D_loss: 0.027, G_loss: 5.677
# Epoch 207/500 - D_loss: 0.064, G_loss: 6.659
# Epoch 208/500 - D_loss: 0.077, G_loss: 6.307
# Epoch 209/500 - D_loss: 0.127, G_loss: 7.017
# Epoch 210/500 - D_loss: 0.016, G_loss: 5.247
# Epoch 211/500 - D_loss: 0.064, G_loss: 4.305
# Epoch 212/500 - D_loss: 0.103, G_loss: 2.954
# Epoch 213/500 - D_loss: 0.030, G_loss: 5.449
# Epoch 214/500 - D_loss: 0.078, G_loss: 7.501
# Epoch 215/500 - D_loss: 0.115, G_loss: 7.392
# Epoch 216/500 - D_loss: 0.067, G_loss: 4.644
# Epoch 217/500 - D_loss: 0.071, G_loss: 4.076
# Epoch 218/500 - D_loss: 0.023, G_loss: 6.410
# Epoch 219/500 - D_loss: 0.121, G_loss: 7.081
# Epoch 220/500 - D_loss: 0.010, G_loss: 6.620
# Epoch 221/500 - D_loss: 0.058, G_loss: 4.974
# Epoch 222/500 - D_loss: 0.015, G_loss: 6.765
# Epoch 223/500 - D_loss: 0.036, G_loss: 6.058
# Epoch 224/500 - D_loss: 0.044, G_loss: 5.872
# Epoch 225/500 - D_loss: 0.088, G_loss: 6.653
# Epoch 226/500 - D_loss: 0.769, G_loss: 0.205
# Epoch 227/500 - D_loss: 0.029, G_loss: 5.505
# Epoch 228/500 - D_loss: 0.110, G_loss: 4.749
# Epoch 229/500 - D_loss: 0.228, G_loss: 9.149
# Epoch 230/500 - D_loss: 0.087, G_loss: 6.092
# Epoch 231/500 - D_loss: 0.075, G_loss: 4.484
# Epoch 232/500 - D_loss: 0.076, G_loss: 6.543
# Epoch 233/500 - D_loss: 0.092, G_loss: 4.193
# Epoch 234/500 - D_loss: 0.124, G_loss: 4.821
# Epoch 235/500 - D_loss: 0.034, G_loss: 7.450
# Epoch 236/500 - D_loss: 0.068, G_loss: 7.015
# Epoch 237/500 - D_loss: 0.051, G_loss: 4.827
# Epoch 238/500 - D_loss: 0.159, G_loss: 7.537
# Epoch 239/500 - D_loss: 0.085, G_loss: 6.899
# Epoch 240/500 - D_loss: 0.050, G_loss: 4.735
# Epoch 241/500 - D_loss: 0.158, G_loss: 8.222
# Epoch 242/500 - D_loss: 0.022, G_loss: 5.347
# Epoch 243/500 - D_loss: 0.077, G_loss: 6.937
# Epoch 244/500 - D_loss: 0.015, G_loss: 6.406
# Epoch 245/500 - D_loss: 0.065, G_loss: 7.497
# Epoch 246/500 - D_loss: 0.119, G_loss: 4.277
# Epoch 247/500 - D_loss: 0.055, G_loss: 4.680
# Epoch 248/500 - D_loss: 0.084, G_loss: 5.137
# Epoch 249/500 - D_loss: 0.034, G_loss: 4.920
# Epoch 250/500 - D_loss: 0.035, G_loss: 4.609
# Epoch 251/500 - D_loss: 0.074, G_loss: 4.566
# Epoch 252/500 - D_loss: 0.012, G_loss: 8.179
# Epoch 253/500 - D_loss: 0.062, G_loss: 5.344
# Epoch 254/500 - D_loss: 0.021, G_loss: 6.388
# Epoch 255/500 - D_loss: 0.011, G_loss: 6.908
# Epoch 256/500 - D_loss: 0.030, G_loss: 7.716
# Epoch 257/500 - D_loss: 0.035, G_loss: 6.069
# Epoch 258/500 - D_loss: 0.046, G_loss: 8.636
# Epoch 259/500 - D_loss: 0.187, G_loss: 3.284
# Epoch 260/500 - D_loss: 0.009, G_loss: 6.543
# Epoch 261/500 - D_loss: 0.019, G_loss: 5.798
# Epoch 262/500 - D_loss: 0.083, G_loss: 4.322
# Epoch 263/500 - D_loss: 0.062, G_loss: 6.276
# Epoch 264/500 - D_loss: 0.017, G_loss: 11.574
# Epoch 265/500 - D_loss: 0.046, G_loss: 5.368
# Epoch 266/500 - D_loss: 0.031, G_loss: 6.219
# Epoch 267/500 - D_loss: 0.286, G_loss: 14.007
# Epoch 268/500 - D_loss: 0.131, G_loss: 2.887
# Epoch 269/500 - D_loss: 0.011, G_loss: 5.567
# Epoch 270/500 - D_loss: 0.136, G_loss: 5.586
# Epoch 271/500 - D_loss: 0.032, G_loss: 6.496
# Epoch 272/500 - D_loss: 0.019, G_loss: 6.984
# Epoch 273/500 - D_loss: 0.040, G_loss: 7.731
# Epoch 274/500 - D_loss: 0.027, G_loss: 6.443
# Epoch 275/500 - D_loss: 0.070, G_loss: 5.339
# Epoch 276/500 - D_loss: 0.034, G_loss: 5.423
# Epoch 277/500 - D_loss: 0.138, G_loss: 7.362
# Epoch 278/500 - D_loss: 0.095, G_loss: 4.023
# Epoch 279/500 - D_loss: 0.053, G_loss: 5.125
# Epoch 280/500 - D_loss: 0.052, G_loss: 7.146
# Epoch 281/500 - D_loss: 0.068, G_loss: 8.365
# Epoch 282/500 - D_loss: 0.087, G_loss: 4.955
# Epoch 283/500 - D_loss: 0.125, G_loss: 5.494
# Epoch 284/500 - D_loss: 0.134, G_loss: 3.452
# Epoch 285/500 - D_loss: 0.054, G_loss: 4.548
# Epoch 286/500 - D_loss: 0.047, G_loss: 6.024
# Epoch 287/500 - D_loss: 0.082, G_loss: 7.317
# Epoch 288/500 - D_loss: 0.058, G_loss: 4.870
# Epoch 289/500 - D_loss: 0.059, G_loss: 5.080
# Epoch 290/500 - D_loss: 0.034, G_loss: 5.957
# Epoch 291/500 - D_loss: 0.193, G_loss: 3.640
# Epoch 292/500 - D_loss: 0.033, G_loss: 5.537
# Epoch 293/500 - D_loss: 0.112, G_loss: 4.443
# Epoch 294/500 - D_loss: 0.066, G_loss: 3.434
# Epoch 295/500 - D_loss: 0.054, G_loss: 7.222
# Epoch 296/500 - D_loss: 0.037, G_loss: 5.501
# Epoch 297/500 - D_loss: 0.007, G_loss: 5.807
# Epoch 298/500 - D_loss: 0.066, G_loss: 5.366
# Epoch 299/500 - D_loss: 0.018, G_loss: 4.535
# Epoch 300/500 - D_loss: 0.017, G_loss: 6.870
# Epoch 301/500 - D_loss: 0.054, G_loss: 6.543
# Epoch 302/500 - D_loss: 0.040, G_loss: 7.201
# Epoch 303/500 - D_loss: 0.109, G_loss: 7.648
# Epoch 304/500 - D_loss: 0.024, G_loss: 5.368
# Epoch 305/500 - D_loss: 0.035, G_loss: 5.506
# Epoch 306/500 - D_loss: 0.058, G_loss: 5.091
# Epoch 307/500 - D_loss: 0.073, G_loss: 7.010
# Epoch 308/500 - D_loss: 0.012, G_loss: 5.432
# Epoch 309/500 - D_loss: 0.078, G_loss: 9.885
# Epoch 310/500 - D_loss: 0.054, G_loss: 4.570
# Epoch 311/500 - D_loss: 0.254, G_loss: 12.295
# Epoch 312/500 - D_loss: 0.015, G_loss: 6.884
# Epoch 313/500 - D_loss: 0.048, G_loss: 6.258
# Epoch 314/500 - D_loss: 0.137, G_loss: 6.245
# Epoch 315/500 - D_loss: 0.022, G_loss: 4.590
# Epoch 316/500 - D_loss: 0.091, G_loss: 6.328
# Epoch 317/500 - D_loss: 0.034, G_loss: 7.970
# Epoch 318/500 - D_loss: 0.011, G_loss: 6.179
# Epoch 319/500 - D_loss: 0.014, G_loss: 6.913
# Epoch 320/500 - D_loss: 0.041, G_loss: 5.431
# Epoch 321/500 - D_loss: 0.017, G_loss: 7.408
# Epoch 322/500 - D_loss: 0.024, G_loss: 5.072
# Epoch 323/500 - D_loss: 0.179, G_loss: 4.451
# Epoch 324/500 - D_loss: 0.022, G_loss: 5.691
# Epoch 325/500 - D_loss: 0.022, G_loss: 6.784
# Epoch 326/500 - D_loss: 0.006, G_loss: 5.603
# Epoch 327/500 - D_loss: 0.030, G_loss: 5.115
# Epoch 328/500 - D_loss: 0.061, G_loss: 7.524
# Epoch 329/500 - D_loss: 0.177, G_loss: 4.599
# Epoch 330/500 - D_loss: 0.083, G_loss: 8.585
# Epoch 331/500 - D_loss: 0.009, G_loss: 9.124
# Epoch 332/500 - D_loss: 0.056, G_loss: 8.299
# Epoch 333/500 - D_loss: 0.042, G_loss: 4.216
# Epoch 334/500 - D_loss: 0.054, G_loss: 7.059
# Epoch 335/500 - D_loss: 0.052, G_loss: 5.836
# Epoch 336/500 - D_loss: 0.011, G_loss: 6.245
# Epoch 337/500 - D_loss: 0.142, G_loss: 8.199
# Epoch 338/500 - D_loss: 0.014, G_loss: 5.488
# Epoch 339/500 - D_loss: 0.111, G_loss: 4.584
# Epoch 340/500 - D_loss: 0.050, G_loss: 6.557
# Epoch 341/500 - D_loss: 0.090, G_loss: 7.844
# Epoch 342/500 - D_loss: 0.102, G_loss: 5.576
# Epoch 343/500 - D_loss: 0.031, G_loss: 6.029
# Epoch 344/500 - D_loss: 0.145, G_loss: 8.615
# Epoch 345/500 - D_loss: 0.074, G_loss: 4.777
# Epoch 346/500 - D_loss: 0.062, G_loss: 6.984
# Epoch 347/500 - D_loss: 0.028, G_loss: 7.374
# Epoch 348/500 - D_loss: 0.042, G_loss: 4.939
# Epoch 349/500 - D_loss: 0.009, G_loss: 6.536
# Epoch 350/500 - D_loss: 0.030, G_loss: 7.256
# Epoch 351/500 - D_loss: 0.024, G_loss: 6.116
# Epoch 352/500 - D_loss: 0.043, G_loss: 5.756
# Epoch 353/500 - D_loss: 0.088, G_loss: 6.903
# Epoch 354/500 - D_loss: 0.021, G_loss: 6.632
# Epoch 355/500 - D_loss: 0.028, G_loss: 7.885
# Epoch 356/500 - D_loss: 0.034, G_loss: 6.636
# Epoch 357/500 - D_loss: 0.002, G_loss: 12.087
# Epoch 358/500 - D_loss: 0.033, G_loss: 5.989
# Epoch 359/500 - D_loss: 0.054, G_loss: 5.926
# Epoch 360/500 - D_loss: 0.020, G_loss: 6.613
# Epoch 361/500 - D_loss: 0.035, G_loss: 6.480
# Epoch 362/500 - D_loss: 0.041, G_loss: 6.267
# Epoch 363/500 - D_loss: 0.043, G_loss: 6.043
# Epoch 364/500 - D_loss: 0.073, G_loss: 10.799
# Epoch 365/500 - D_loss: 0.045, G_loss: 6.143
# Epoch 366/500 - D_loss: 0.007, G_loss: 6.806
# Epoch 367/500 - D_loss: 0.071, G_loss: 4.929
# Epoch 368/500 - D_loss: 0.010, G_loss: 6.161
# Epoch 369/500 - D_loss: 0.007, G_loss: 7.653
# Epoch 370/500 - D_loss: 0.064, G_loss: 6.666
# Epoch 371/500 - D_loss: 0.019, G_loss: 5.368
# Epoch 372/500 - D_loss: 0.022, G_loss: 8.159
# Epoch 373/500 - D_loss: 0.111, G_loss: 3.290
# Epoch 374/500 - D_loss: 0.013, G_loss: 7.846
# Epoch 375/500 - D_loss: 0.016, G_loss: 6.012
# Epoch 376/500 - D_loss: 0.017, G_loss: 5.053
# Epoch 377/500 - D_loss: 0.187, G_loss: 8.483
# Epoch 378/500 - D_loss: 0.042, G_loss: 7.292
# Epoch 379/500 - D_loss: 0.035, G_loss: 8.149
# Epoch 380/500 - D_loss: 0.038, G_loss: 7.942
# Epoch 381/500 - D_loss: 0.031, G_loss: 7.514
# Epoch 382/500 - D_loss: 0.059, G_loss: 7.466
# Epoch 383/500 - D_loss: 0.155, G_loss: 5.994
# Epoch 384/500 - D_loss: 0.005, G_loss: 8.764
# Epoch 385/500 - D_loss: 0.052, G_loss: 5.288
# Epoch 386/500 - D_loss: 0.054, G_loss: 5.293
# Epoch 387/500 - D_loss: 0.014, G_loss: 6.519
# Epoch 388/500 - D_loss: 0.012, G_loss: 9.438
# Epoch 389/500 - D_loss: 0.017, G_loss: 7.221
# Epoch 390/500 - D_loss: 0.017, G_loss: 5.784
# Epoch 391/500 - D_loss: 0.129, G_loss: 8.520
# Epoch 392/500 - D_loss: 0.093, G_loss: 6.828
# Epoch 393/500 - D_loss: 0.021, G_loss: 6.688
# Epoch 394/500 - D_loss: 0.350, G_loss: 8.657
# Epoch 395/500 - D_loss: 0.033, G_loss: 5.851
# Epoch 396/500 - D_loss: 0.056, G_loss: 6.740
# Epoch 397/500 - D_loss: 0.029, G_loss: 5.083
# Epoch 398/500 - D_loss: 0.007, G_loss: 10.221
# Epoch 399/500 - D_loss: 0.043, G_loss: 6.759
# Epoch 400/500 - D_loss: 0.027, G_loss: 7.228
# Epoch 401/500 - D_loss: 0.053, G_loss: 11.310
# Epoch 402/500 - D_loss: 0.013, G_loss: 8.745
# Epoch 403/500 - D_loss: 0.028, G_loss: 9.239
# Epoch 404/500 - D_loss: 0.032, G_loss: 6.281
# Epoch 405/500 - D_loss: 0.178, G_loss: 9.795
# Epoch 406/500 - D_loss: 0.109, G_loss: 5.373
# Epoch 407/500 - D_loss: 0.017, G_loss: 6.811
# Epoch 408/500 - D_loss: 0.040, G_loss: 6.823
# Epoch 409/500 - D_loss: 0.030, G_loss: 7.118
# Epoch 410/500 - D_loss: 0.013, G_loss: 7.656
# Epoch 411/500 - D_loss: 0.012, G_loss: 8.127
# Epoch 412/500 - D_loss: 0.005, G_loss: 6.725
# Epoch 413/500 - D_loss: 0.028, G_loss: 6.195
# Epoch 414/500 - D_loss: 0.064, G_loss: 6.393
# Epoch 415/500 - D_loss: 0.055, G_loss: 8.355
# Epoch 416/500 - D_loss: 0.026, G_loss: 7.742
# Epoch 417/500 - D_loss: 0.013, G_loss: 6.456
# Epoch 418/500 - D_loss: 0.007, G_loss: 7.939
# Epoch 419/500 - D_loss: 0.060, G_loss: 9.878
# Epoch 420/500 - D_loss: 0.083, G_loss: 5.829
# Epoch 421/500 - D_loss: 0.058, G_loss: 4.825
# Epoch 422/500 - D_loss: 0.006, G_loss: 6.222
# Epoch 423/500 - D_loss: 0.049, G_loss: 5.993
# Epoch 424/500 - D_loss: 0.042, G_loss: 7.792
# Epoch 425/500 - D_loss: 0.035, G_loss: 7.881
# Epoch 426/500 - D_loss: 0.026, G_loss: 5.977
# Epoch 427/500 - D_loss: 0.009, G_loss: 6.371
# Epoch 428/500 - D_loss: 0.095, G_loss: 8.735
# Epoch 429/500 - D_loss: 0.007, G_loss: 6.512
# Epoch 430/500 - D_loss: 0.026, G_loss: 5.019
# Epoch 431/500 - D_loss: 0.028, G_loss: 5.759
# Epoch 432/500 - D_loss: 0.011, G_loss: 6.629
# Epoch 433/500 - D_loss: 0.022, G_loss: 6.160
# Epoch 434/500 - D_loss: 0.018, G_loss: 7.146
# Epoch 435/500 - D_loss: 0.045, G_loss: 6.393
# Epoch 436/500 - D_loss: 0.023, G_loss: 7.381
# Epoch 437/500 - D_loss: 0.020, G_loss: 7.044
# Epoch 438/500 - D_loss: 0.028, G_loss: 7.201
# Epoch 439/500 - D_loss: 0.008, G_loss: 7.666
# Epoch 440/500 - D_loss: 0.014, G_loss: 7.696
# Epoch 441/500 - D_loss: 0.002, G_loss: 8.840
# Epoch 442/500 - D_loss: 0.017, G_loss: 7.066
# Epoch 443/500 - D_loss: 0.029, G_loss: 8.088
# Epoch 444/500 - D_loss: 0.063, G_loss: 7.583
# Epoch 445/500 - D_loss: 0.006, G_loss: 8.193
# Epoch 446/500 - D_loss: 0.027, G_loss: 5.989
# Epoch 447/500 - D_loss: 0.015, G_loss: 9.698
# Epoch 448/500 - D_loss: 0.003, G_loss: 7.380
# Epoch 449/500 - D_loss: 0.052, G_loss: 7.807
# Epoch 450/500 - D_loss: 0.045, G_loss: 6.938
# Epoch 451/500 - D_loss: 0.011, G_loss: 7.277
# Epoch 452/500 - D_loss: 0.008, G_loss: 6.737
# Epoch 453/500 - D_loss: 0.053, G_loss: 6.180
# Epoch 454/500 - D_loss: 0.058, G_loss: 11.304
# Epoch 455/500 - D_loss: 0.022, G_loss: 7.762
# Epoch 456/500 - D_loss: 0.140, G_loss: 3.029
# Epoch 457/500 - D_loss: 0.023, G_loss: 8.255
# Epoch 458/500 - D_loss: 0.040, G_loss: 6.176
# Epoch 459/500 - D_loss: 0.129, G_loss: 14.845
# Epoch 460/500 - D_loss: 0.014, G_loss: 5.630
# Epoch 461/500 - D_loss: 0.013, G_loss: 7.772
# Epoch 462/500 - D_loss: 0.020, G_loss: 11.901
# Epoch 463/500 - D_loss: 0.034, G_loss: 8.822
# Epoch 464/500 - D_loss: 0.022, G_loss: 13.380
# Epoch 465/500 - D_loss: 0.009, G_loss: 5.498
# Epoch 466/500 - D_loss: 0.083, G_loss: 3.543
# Epoch 467/500 - D_loss: 0.070, G_loss: 10.945
# Epoch 468/500 - D_loss: 0.036, G_loss: 5.933
# Epoch 469/500 - D_loss: 0.064, G_loss: 6.078
# Epoch 470/500 - D_loss: 0.385, G_loss: 31.987
# Epoch 471/500 - D_loss: 0.071, G_loss: 6.021
# Epoch 472/500 - D_loss: 0.024, G_loss: 5.956
# Epoch 473/500 - D_loss: 0.013, G_loss: 9.168
# Epoch 474/500 - D_loss: 0.004, G_loss: 15.127
# Epoch 475/500 - D_loss: 0.007, G_loss: 7.953
# Epoch 476/500 - D_loss: 0.006, G_loss: 9.624
# Epoch 477/500 - D_loss: 0.012, G_loss: 6.761
# Epoch 478/500 - D_loss: 0.020, G_loss: 10.784
# Epoch 479/500 - D_loss: 0.080, G_loss: 4.002
# Epoch 480/500 - D_loss: 0.042, G_loss: 8.167
# Epoch 481/500 - D_loss: 0.140, G_loss: 1.900
# Epoch 482/500 - D_loss: 0.009, G_loss: 7.264
# Epoch 483/500 - D_loss: 0.018, G_loss: 7.773
# Epoch 484/500 - D_loss: 0.011, G_loss: 6.512
# Epoch 485/500 - D_loss: 0.039, G_loss: 8.886
# Epoch 486/500 - D_loss: 0.136, G_loss: 10.579
# Epoch 487/500 - D_loss: 0.048, G_loss: 8.891
# Epoch 488/500 - D_loss: 0.017, G_loss: 7.322
# Epoch 489/500 - D_loss: 0.054, G_loss: 5.597
# Epoch 490/500 - D_loss: 0.079, G_loss: 9.938
# Epoch 491/500 - D_loss: 0.016, G_loss: 6.624
# Epoch 492/500 - D_loss: 0.010, G_loss: 8.336
# Epoch 493/500 - D_loss: 0.005, G_loss: 7.345
# Epoch 494/500 - D_loss: 0.002, G_loss: 9.516
# Epoch 495/500 - D_loss: 0.010, G_loss: 8.264
# Epoch 496/500 - D_loss: 0.016, G_loss: 9.367
# Epoch 497/500 - D_loss: 0.178, G_loss: 6.355
# Epoch 498/500 - D_loss: 0.097, G_loss: 6.455
# Epoch 499/500 - D_loss: 0.024, G_loss: 12.457
# Epoch 500/500 - D_loss: 0.006, G_loss: 6.415

# %%
# --------------------------
# Final Visualization: 5 (stages) × 2 (sides)
# --------------------------

netG.eval()

with torch.no_grad():
    # Build grid of latent vectors: one per stage × side
    z = torch.randn(N_STAGES * N_SIDES, NZ, device=DEVICE)

    stages = torch.tensor([s for s in range(N_STAGES) for _ in range(N_SIDES)], device=DEVICE)
    sides  = torch.tensor([side for _ in range(N_STAGES) for side in [0, 1]], device=DEVICE)

    gen_imgs = netG(z, stages, sides).cpu()
    gen_imgs = (gen_imgs + 1) / 2  # [-1,1] → [0,1]

    grid = utils.make_grid(gen_imgs, nrow=N_SIDES, normalize=False)

    plt.figure(figsize=(6, 12))
    plt.imshow(np.transpose(grid, (1,2,0)))
    plt.axis("off")
    plt.title("Generated Progression: Stage (0→4) × Side (Right=0, Left=1)")
    plt.show()

# %%
# --------------------------
# Compare Real vs Generated Samples
# --------------------------

netG.eval()

# Take a small batch from validation set
real_imgs, real_stages, real_sides = next(iter(val_loader))
real_imgs, real_stages, real_sides = real_imgs.to(DEVICE), real_stages.to(DEVICE), real_sides.to(DEVICE)

# Generate using same (stage, side) conditions as real images
with torch.no_grad():
    z = torch.randn(real_imgs.size(0), NZ, device=DEVICE)
    gen_imgs = netG(z, real_stages, real_sides).cpu()
    gen_imgs = (gen_imgs + 1) / 2  # scale to [0,1]

# Prepare real images (also scale to [0,1] for plotting)
real_imgs_disp = (real_imgs.cpu() + 1) / 2

# Build side-by-side grid: first row real, second row generated
comparison = torch.cat([real_imgs_disp, gen_imgs], dim=0)
grid = utils.make_grid(comparison, nrow=real_imgs.size(0), normalize=False)

plt.figure(figsize=(20, 6))
plt.imshow(np.transpose(grid, (1,2,0)))
plt.axis("off")
plt.title("Top Row = Real | Bottom Row = Generated (same stage & side conditions)")
plt.show()

# %%
# !pip install torchmetrics pytorch-ssim --quiet
# Out:
#   DEPRECATION: Building 'pytorch-ssim' using the legacy setup.py bdist_wheel mechanism, which will be removed in a future version. pip 25.3 will enforce this behaviour change. A possible replacement is to use the standardized build interface by setting the `--use-pep517` option, (possibly combined with `--no-build-isolation`), or adding a `pyproject.toml` file to the source tree of 'pytorch-ssim'. Discussion can be found at https://github.com/pypa/pip/issues/6334

# %%
pip install torchmetrics[image] torch-fidelity --quiet
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
# Load checkpoint
checkpoint = torch.load(f"{SAVE_DIR}/checkpoint_epoch_200.pth", map_location=DEVICE)

# Recreate models
netG = Generator(NZ, n_stage=N_STAGES, n_side=N_SIDES).to(DEVICE)
netD = Discriminator(n_stage=N_STAGES, n_side=N_SIDES).to(DEVICE)

netG.load_state_dict(checkpoint["netG_state_dict"])
netD.load_state_dict(checkpoint["netD_state_dict"])
netG.eval()

print(f"Checkpoint loaded (epoch {checkpoint['epoch']})")
# Out:
# Checkpoint loaded (epoch 200)

# %%
import torchvision.utils as vutils
import matplotlib.pyplot as plt

def generate_progression(netG, z=None, save_path=None):
    netG.eval()
    if z is None:
        z = torch.randn(1, NZ, device=DEVICE)  # one random patient

    images = []
    with torch.no_grad():
        for side in [0, 1]:   # right=0, left=1
            row_imgs = []
            for stage in range(N_STAGES):  # stages 0..4
                stage_t = torch.tensor([stage], device=DEVICE)
                side_t  = torch.tensor([side], device=DEVICE)
                img = netG(z, stage_t, side_t).cpu()
                img = (img + 1) / 2.0  # back to [0,1]
                row_imgs.append(img)
            images.append(torch.cat(row_imgs, dim=0))

    # Stack into grid: 2 rows (sides), 5 cols (stages)
    grid = vutils.make_grid(torch.cat(images, dim=0), nrow=N_STAGES, normalize=False, pad_value=1)

    plt.figure(figsize=(12, 5))
    plt.imshow(np.transpose(grid, (1, 2, 0)))
    plt.axis("off")
    plt.title("Stage-wise Disease Progression (Top=Right Knee, Bottom=Left Knee)")
    plt.show()

    if save_path:
        vutils.save_image(grid, save_path)

# Example usage
z_patient = torch.randn(1, NZ, device=DEVICE)
generate_progression(netG, z_patient, save_path=f"{SAVE_DIR}/progression_patient.png")

# %%
# --------------------------
# Compare Real vs Generated Samples
# --------------------------

netG.eval()

# Take a small batch from validation set
real_imgs, real_stages, real_sides = next(iter(val_loader))
real_imgs, real_stages, real_sides = real_imgs.to(DEVICE), real_stages.to(DEVICE), real_sides.to(DEVICE)

# Generate using same (stage, side) conditions as real images
with torch.no_grad():
    z = torch.randn(real_imgs.size(0), NZ, device=DEVICE)
    gen_imgs = netG(z, real_stages, real_sides).cpu()
    gen_imgs = (gen_imgs + 1) / 2  # scale to [0,1]

# Prepare real images (also scale to [0,1] for plotting)
real_imgs_disp = (real_imgs.cpu() + 1) / 2

# Build side-by-side grid: first row real, second row generated
comparison = torch.cat([real_imgs_disp, gen_imgs], dim=0)
grid = utils.make_grid(comparison, nrow=real_imgs.size(0), normalize=False)

plt.figure(figsize=(20, 6))
plt.imshow(np.transpose(grid, (1,2,0)))
plt.axis("off")
plt.title("Top Row = Real | Bottom Row = Generated (same stage & side conditions)")
plt.show()

# %%
import glob

def load_real_progression(patient_id, side, data_root, stages=[0,1,2,3,4]):
    images = []
    for stage in stages:
        stage_dir = os.path.join(data_root, "train", str(stage))
        # match both .png and .PNG
        matches = glob.glob(os.path.join(stage_dir, f"{patient_id}_{side}.*"))
        
        if len(matches) > 0:
            fpath = matches[0]
            img = Image.open(fpath).convert("L")
            img = img.resize((128,128))
            img = np.array(img) / 255.0
            images.append(img)
        else:
            print(f"⚠️ Missing: patient {patient_id}, side {side}, stage {stage}")
            images.append(np.zeros((128,128)))
    return images

# %%
import os
import matplotlib.pyplot as plt
import torchvision.utils as vutils
from PIL import Image
import numpy as np

# Function to load real images for a given patient_id and side
def load_real_progression(patient_id, side, data_root, stages=[0,1,2,3,4]):
    images = []
    for stage in stages:
        stage_dir = os.path.join(data_root, "auto_test", str(stage))  # adjust if you want val/test
        fname = f"{patient_id}_{side}.png"
        print(fname)
        print(stage_dir)
        fpath = os.path.join(stage_dir, fname)
        if os.path.exists(fpath):
            img = Image.open(fpath).convert("L")  # grayscale
            img = img.resize((128,128))  # resize to match GAN output
            img = np.array(img) / 255.0
            images.append(img)
        else:
            # if missing, append blank
            images.append(np.zeros((128,128)))
    return images

# Function to generate progression from GAN
def generate_fake_progression(netG, z, side, stages=[0,1,2,3,4]):
    images = []
    with torch.no_grad():
        for stage in stages:
            stage_t = torch.tensor([stage], device=DEVICE)
            side_t  = torch.tensor([side], device=DEVICE)
            img = netG(z, stage_t, side_t).cpu()
            img = (img + 1) / 2.0  # scale to [0,1]
            img = img.squeeze(0).permute(1,2,0).numpy()
            images.append(img)
    return images

# Function to plot real vs fake progression
def compare_progression(patient_id, side, data_root, netG, z=None, save_path=None):
    if z is None:
        z = torch.randn(1, NZ, device=DEVICE)
    
    real_imgs = load_real_progression(patient_id, side, data_root)
    fake_imgs = generate_fake_progression(netG, z, side)

    fig, axes = plt.subplots(2, len(real_imgs), figsize=(15, 6))
    
    for i in range(len(real_imgs)):
        axes[0, i].imshow(real_imgs[i], cmap="gray")
        axes[0, i].axis("off")
        axes[0, i].set_title(f"Real Stage {i}")
        
        axes[1, i].imshow(fake_imgs[i].squeeze(), cmap="gray")
        axes[1, i].axis("off")
        axes[1, i].set_title(f"Fake Stage {i}")
    
    plt.suptitle(f"Patient {patient_id}, Side {side} Progression (Real vs GAN)", fontsize=14)
    plt.tight_layout()
    if save_path:
        plt.savefig(save_path)
    plt.show()

# Example usage:
data_root = path  # from kagglehub download
print(data_root)
patient_id = "9003175"
side = 1  # right knee (use 2 for left)
compare_progression(patient_id, side, data_root, netG, save_path=f"{SAVE_DIR}/real_vs_fake.png")
# Out:
# C:\Users\Sanjjey Arumugam\.cache\kagglehub\datasets\jeftaadriel\osteoarthritis-initiative-oai-dataset\versions\1
# 9003175_1.png
# C:\Users\Sanjjey Arumugam\.cache\kagglehub\datasets\jeftaadriel\osteoarthritis-initiative-oai-dataset\versions\1\auto_test\0
# 9003175_1.png
# C:\Users\Sanjjey Arumugam\.cache\kagglehub\datasets\jeftaadriel\osteoarthritis-initiative-oai-dataset\versions\1\auto_test\1
# 9003175_1.png
# C:\Users\Sanjjey Arumugam\.cache\kagglehub\datasets\jeftaadriel\osteoarthritis-initiative-oai-dataset\versions\1\auto_test\2
# 9003175_1.png
# C:\Users\Sanjjey Arumugam\.cache\kagglehub\datasets\jeftaadriel\osteoarthritis-initiative-oai-dataset\versions\1\auto_test\3
# 9003175_1.png
# C:\Users\Sanjjey Arumugam\.cache\kagglehub\datasets\jeftaadriel\osteoarthritis-initiative-oai-dataset\versions\1\auto_test\4

# %%
# Application: Generate OA Progression from a Healthy Knee X-ray

import torch
from torchvision import transforms
from PIL import Image
import matplotlib.pyplot as plt
import numpy as np

def generate_progression(input_image_path, side, generator_model, device='cuda'):
    """
    Generates and displays the progression of osteoarthritis from a healthy knee X-ray.

    Args:
        input_image_path (str): The file path to the healthy (stage 0) knee X-ray image.
        side (int): The side of the knee (0 for right, 1 for left).
        generator_model (torch.nn.Module): The trained generator model.
        device (str): The device to run the model on ('cuda' or 'cpu').
    """
    # Load and preprocess the input image
    transform = transforms.Compose([
        transforms.Resize((IMG_SIZE, IMG_SIZE)),
        transforms.Grayscale(num_output_channels=1),
        transforms.ToTensor(),
        transforms.Normalize([0.5], [0.5])
    ])
    
    input_image = Image.open(input_image_path).convert("L")
    input_tensor = transform(input_image).unsqueeze(0).to(device)

    # Generate images for stages 1 to 4
    generator_model.eval()
    with torch.no_grad():
        # Use a fixed random noise vector for all stages to maintain consistency
        z = torch.randn(1, NZ, device=device)
        
        generated_images = []
        for stage in range(1, 5):
            stage_tensor = torch.tensor([stage], device=device)
            side_tensor = torch.tensor([side], device=device)
            generated_img = generator_model(z, stage_tensor, side_tensor).cpu()
            generated_images.append(generated_img.squeeze(0))

    # Display the results
    fig, axes = plt.subplots(1, 5, figsize=(15, 3))
    
    # Original Image (Stage 0)
    axes[0].imshow(input_image, cmap='gray')
    axes[0].set_title("Input: Healthy (Stage 0)")
    axes[0].axis('off')
    
    # Generated Images (Stages 1-4)
    for i, img in enumerate(generated_images):
        img_display = (img + 1) / 2  # Denormalize
        axes[i+1].imshow(np.transpose(img_display, (1,2,0)), cmap='gray')
        axes[i+1].set_title(f"Generated: Stage {i+1}")
        axes[i+1].axis('off')
        
    plt.suptitle(f"Generated OA Progression (Side: {'Right' if side == 0 else 'Left'})", fontsize=16)
    plt.show()

# --- Example Usage ---

# **Important**: Before running this, make sure you have a trained generator model (`netG`).
# If you have saved a checkpoint, you can load it like this:
# checkpoint = torch.load(f"{SAVE_DIR}/checkpoint_epoch_500.pth")
# netG.load_state_dict(checkpoint['netG_state_dict'])

# You'll need a path to a healthy knee x-ray image from the dataset.
# Here, we'll find a random stage 0 image from the training set.
import random
stage_0_images = [s[0] for s in train_ds.samples if s[1] == 0 and s[2] == 0] # Stage 0, Right Knee
if stage_0_images:
    healthy_knee_image_path = random.choice(stage_0_images)
    print(f"Using healthy knee image: {healthy_knee_image_path}")

    # Generate the progression for the right knee (side=0)
    generate_progression(healthy_knee_image_path, 0, netG, DEVICE)
else:
    print("No stage 0 images found in the training set for the right knee.")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 71
#      61 # --- Example Usage ---
#      62
#      63 # **Important**: Before running this, make sure you have a trained generator model (`netG`).
#    (...)
#      68 # You'll need a path to a healthy knee x-ray image from the dataset.
#      69 # Here, we'll find a random stage 0 image from the training set.
#      70 import random
# ---> 71 stage_0_images = [s[0] for s in train_ds.samples if s[1] == 0 and s[2] == 0] # Stage 0, Right Knee
#      72 if stage_0_images:
#      73     healthy_knee_image_path = random.choice(stage_0_images)
#
# NameError: name 'train_ds' is not defined
